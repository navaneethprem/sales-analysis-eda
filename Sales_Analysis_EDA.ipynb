# %%
# !pip install openpyxl
import pandas as pd
df=pd.read_excel('/content/Messy_Sales_Data.xlsx')
# Out:
# Requirement already satisfied: openpyxl in /usr/local/lib/python3.11/dist-packages (3.1.5)
# Requirement already satisfied: et-xmlfile in /usr/local/lib/python3.11/dist-packages (from openpyxl) (2.0.0)

# %% [markdown]
# # New Section

# %%
df.head()
# Out:
#         Date Region  Sales  Profit
# 0 2025-06-01  North   1000     200
# 1 2025-06-02  South   1200     240
# 2 2025-06-04   West    950     190
# 3 2025-06-05  North   1100     220
# 4 2025-06-06  South   1050     210

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    6 non-null      datetime64[ns]
#  1   Region  6 non-null      object
#  2   Sales   6 non-null      int64
#  3   Profit  6 non-null      int64
# dtypes: datetime64[ns](1), int64(2), object(1)
# memory usage: 324.0+ bytes

# %%
df.describe()
# Out:
#                       Date        Sales      Profit
# count                    6     6.000000    6.000000
# mean   2025-06-04 04:00:00  1048.333333  209.666667
# min    2025-06-01 00:00:00   950.000000  190.000000
# 25%    2025-06-02 12:00:00   992.500000  198.500000
# 50%    2025-06-04 12:00:00  1025.000000  205.000000
# 75%    2025-06-05 18:00:00  1087.500000  217.500000
# max    2025-06-07 00:00:00  1200.000000  240.000000
# std                    NaN    90.645831   18.129166

# %%
print("Total Sales:",df['Sales'].sum())
print("Average Profits:",df['Profit'].mean())
# Out:
# Total Sales: 6290
# Average Profits: 209.66666666666666

# %%
print(df.columns)
# Out:
# Index(['Date', 'Region', 'Sales', 'Profit'], dtype='object')

# %%
df.groupby('Region')[['Sales', 'Profit']].agg(['sum', 'mean'])
# Out:
#        Sales         Profit
#          sum    mean    sum   mean
# Region
# East     990   990.0    198  198.0
# North   2100  1050.0    420  210.0
# South   2250  1125.0    450  225.0
# West     950   950.0    190  190.0

# %%
import matplotlib.pyplot as plt
import seaborn as sns


sns.set(style="whitegrid")


region_sales = df.groupby('Region')['Sales'].sum().reset_index()

plt.figure(figsize=(8, 5))
sns.barplot(x='Region', y='Sales', data=region_sales, palette='Blues_d')
plt.title('Total Sales by Region')
plt.ylabel('Total Sales')
plt.xlabel('Region')
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-12-946969721>:11: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Region', y='Sales', data=region_sales, palette='Blues_d')
